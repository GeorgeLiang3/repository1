# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow_probability import edward2 as ed
tfd = tfp.distributions

import seaborn as sns
import pandas as pd
# %matplotlib inline
np.random.seed(111)
# tf.set_random_seed(111)

# %%
@tf.function
def grav_analytical(x, sphere_center, sphere_radius, density_difference):
    """Calculate gravitational effect of a sphere, measured at surface
    
    **Arguments**:
    - 'x' = scalar or np.array: position(s) of observation
    - 'sphere_center' = float: is the vertical position of the center of the sphere (lateral position at origin)
    - 'sphere_radius' = float: sphere radius
    - 'density_difference' = float: density difference to the surrounding domain
    """
    G= tf.constant(6.67e-11,dtype) # gravitational constant
    return (tf.constant(4/3,dtype)* tf.constant(np.pi,dtype) * (sphere_radius**3) * density_difference
            * G * sphere_center/(x**2 + sphere_center**2)**tf.constant(3/2,dtype)) * tf.constant(1e5,dtype)

# %%
dtype = tf.float32

# %%
sphere_center = tf.constant(300.,dtype) #m 
sphere_radius = tf.constant(100.,dtype) #m
density_difference = tf.constant(500.,dtype) # kg/m^3: density diffrence to surrounding domain
x_domain=tf.linspace(tf.constant(-1000.,dtype),tf.constant(1000.,dtype),101) #m

# %%
x_obs = tf.linspace(tf.constant(-250,dtype), tf.constant(250,dtype), 11)
grav_all = grav_analytical(x_domain, sphere_center, sphere_radius, density_difference)
grav_obs_array = grav_analytical(x_obs, sphere_center, sphere_radius, density_difference)
noise = norm(0,0.01).rvs(len(grav_obs_array))
grav_obs_array_noise = grav_obs_array + noise

# %%
grav_obs_array_noise
# Out:
# <tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([0.05903379, 0.09325413, 0.12603045, 0.12897359, 0.1410927 ,
#        0.15062355, 0.14837636, 0.12898567, 0.10370968, 0.07757154,
#        0.07276111], dtype=float32)>

# %%
sphere_center_samples
# Out:
# <tf.Tensor: shape=(10000,), dtype=float32, numpy=
# array([274.9714 , 274.82138, 274.89664, ..., 278.58356, 278.92508,
#        278.89203], dtype=float32)>

# %%
plt.style.use('seaborn-darkgrid')
ax = plt.subplot(aspect='equal') 

# create circle object as matplotlib patch
circle1 = plt.Circle((0, -sphere_center.numpy()), sphere_radius.numpy(), 
                     facecolor='r', edgecolor='k', alpha=0.5)

ax.add_artist(circle1)

# set model domain
ax.set_xlim([-1000,1000])
ax.set_ylim([-800,10])

ax.set_xlabel("X [m]")
ax.set_ylabel("Y [m]")
# plt.savefig('./Simple_grav_img/SG_noise_3_para/model.png')
# Out:
# Text(0, 0.5, 'Y [m]')

# %%
plt.plot(x_domain, grav_all)
plt.plot(x_obs, grav_obs_array_noise, 'o', label="data")
plt.title("Gravity response for a sphere of radius 100 m and a depth of 300 m");
# plt.savefig('./Simple_grav_img/SG_noise_3_para/gravity.png')

# %%
dtype = tf.float32

# %%
cov_likelihood = 0.01*tf.eye(11)

# %%
# create a log-likelihood function
@tf.function
def log_posterior(D,_sphere_center, _density_difference,_sphere_radius):
    
    sphere_center = tfd.normal.Normal(
            loc = 280.,scale = 10, name = "sphere_center")
    density_difference = tfd.normal.Normal(
            loc = 480.,scale = 10, name = "density_difference")
    sphere_radius = tfd.normal.Normal(
            loc = 80.,scale = 10, name = "sphere_radius")
    G=tf.constant(6.67e-11,dtype) # gravitational constant
    
    grav_ = grav_analytical(x_obs, _sphere_center, _sphere_radius, _density_difference)

#     gravity = ((4/3)*np.pi * (sphere_radius**3) * density_difference* G * sphere_center/(x**2 + sphere_center**2)**(3/2)) * 1e5 
    gravity = tfd.MultivariateNormalTriL(loc = grav_,
                                         scale_tril=tf.linalg.cholesky(cov_likelihood))
    
    log_joint_post = (sphere_center.log_prob(_sphere_center) + 
                      density_difference.log_prob(_density_difference)+
                      sphere_radius.log_prob(_sphere_radius)+
                     gravity.log_prob(D))
    

    return log_joint_post

# %% [markdown]
# ### Different expresion of a joint normal distribution

# %%
cov = [100,100,10]*tf.eye(3)

# %%
a = tfd.MultivariateNormalTriL(loc = ([280,480,80]),scale_tril=tf.linalg.cholesky(cov))

# %%
a.log_prob([10,10,10])
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=-1722.5133>

# %%
sphere_center = tfd.normal.Normal(
            loc = 280.,scale = 10)
density_difference = tfd.normal.Normal(
        loc = 480.,scale = 10, name = "density_difference")
sphere_radius = tfd.normal.Normal(
        loc = 80.,scale = 10, name = "sphere_radius")

sphere_center.log_prob(10)+density_difference.log_prob(10)+sphere_radius.log_prob(10)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=-1503.1647>

# %% [markdown]
# ## MCMC

# %%
num_results = int(10e4) #number of hmc iterations
n_burnin = int(5e3)     #number of burn-in steps

step_size = 0.1
num_leapfrog_steps = 10

# %% [markdown]
# ### HMC

# %%
# HMC transition kernel
@tf.function
def unnormalized_posterior_log_prob(*args):
    return log_posterior(grav_obs_array_noise,*args)

kernel = tfp.mcmc.HamiltonianMonteCarlo(
    target_log_prob_fn=unnormalized_posterior_log_prob,
    step_size=step_size,
    num_leapfrog_steps=num_leapfrog_steps)

@tf.function
def run_chain():
    # Define the chain states
    states, kernel_results = tfp.mcmc.sample_chain(
        num_results=num_results,
        num_burnin_steps=n_burnin,
        kernel=kernel,

        #set initial state (drawn from prior)
        current_state=[
            tf.random.normal([], mean=280, stddev=10, dtype=tf.float32),
            tf.random.normal([], mean=480, stddev=10, dtype=tf.float32),
            tf.random.normal([], mean=80, stddev=10, dtype=tf.float32)
        ])
    
    sphere_center,density_difference,sphere_radius = states
    return sphere_center,density_difference,sphere_radius,kernel_results

sphere_center,density_difference,sphere_radius,kernel_results = run_chain()
# Out:
# /Users/zhouji/anaconda3/envs/bys/lib/python3.7/site-packages/tensorflow_probability/python/mcmc/sample.py:333: UserWarning: Tracing all kernel results by default is deprecated. Set the `trace_fn` argument to None (the future default value) or an explicit callback that traces the values you are interested in.
#   warnings.warn("Tracing all kernel results by default is deprecated. Set "

# %%
sphere_center_samples = sphere_center.numpy()
density_difference_samples = density_difference.numpy()
sphere_radius_samples = sphere_radius.numpy()
is_accepted_ = kernel_results.is_accepted

print('Acceptance rate: %0.1f%%' % (100*tf.reduce_mean(tf.cast(is_accepted_, dtype=tf.float32))))
# Out:
# Acceptance rate: 100.0%

# %%
def chain_plot(data, title='', ax=None):
  '''Plot both chain and posterior distribution'''
  if ax is None:
    ax = plt.gca()
  ax.plot(data)
  ax.title.set_text(title+" chain")
    
def post_plot(data, title='', ax=None, true=None, prc=95):
  '''Plot the posterior distribution given MCMC samples'''
  if ax is None:
    ax = plt.gca()
  sns.kdeplot(data, ax=ax, shade=True)
  tprc = (100-prc)/2
  
  ax.axvline(x=np.percentile(data, tprc), linestyle='--')
  ax.axvline(x=np.percentile(data, 100-tprc), linestyle='--')
  ax.title.set_text(title+" distribution")
  if true is not None:
    ax.axvline(x=true)

    
def chain_post_plot(data, title='', ax=None, true=None):
  '''Plot a chain of MCMC samples'''
  chain_plot(data, title=title, ax=ax[0])
  post_plot(data, title=title, ax=ax[1], true=true)

# %%
fig, axes = plt.subplots(3, 2, sharex=False, sharey=False)
fig.set_size_inches(15, 10)

chain_post_plot(sphere_center_samples[:,],
                  title="sphere_center",
                  ax=axes[0], true=300)

chain_post_plot(density_difference_samples[:,],
                  title="density_difference",
                  ax=axes[1], true=500)

chain_post_plot(sphere_radius_samples[:,],
                  title="sphere_radius",
                  ax=axes[2], true=100)

# plt.savefig('./Simple_grav_img/HMC_0_noise.png')

# %% [markdown]
# #### RMH MCMC

# %%
num_results = int(10e4) #number of hmc iterations
n_burnin = int(5e3)     #number of burn-in steps

# %%
kernel=tfp.mcmc.RandomWalkMetropolis(
     target_log_prob_fn=unnormalized_posterior_log_prob,
     seed=40)

@tf.function
def run_chain():
    # Define the chain states
    states, kernel_results = tfp.mcmc.sample_chain(
        num_results=num_results,
        num_burnin_steps=n_burnin,
        kernel=kernel,

        #set initial state (drawn from prior)
        current_state=[
            tf.random.normal([], mean=280, stddev=10, dtype=tf.float32),
            tf.random.normal([], mean=480, stddev=10, dtype=tf.float32),
            tf.random.normal([], mean=80, stddev=10, dtype=tf.float32)
        ])
    
    sphere_center,density_difference,sphere_radius = states
    return sphere_center,density_difference,sphere_radius,kernel_results

sphere_center,density_difference,sphere_radius,kernel_results = run_chain()
# Out:
# /Users/zhouji/anaconda3/envs/bys/lib/python3.7/site-packages/tensorflow_probability/python/mcmc/sample.py:333: UserWarning: Tracing all kernel results by default is deprecated. Set the `trace_fn` argument to None (the future default value) or an explicit callback that traces the values you are interested in.
#   warnings.warn("Tracing all kernel results by default is deprecated. Set "

# %%
fig, axes = plt.subplots(3, 2, sharex=False, sharey=False)
fig.set_size_inches(15, 10)

chain_post_plot(sphere_center_samples[:,],
                  title="sphere_center",
                  ax=axes[0], true=300)

chain_post_plot(density_difference_samples[:,],
                  title="density_difference",
                  ax=axes[1], true=500)

chain_post_plot(sphere_radius_samples[:,],
                  title="sphere_radius",
                  ax=axes[2], true=100)


# plt.savefig('./Simple_grav_img/RMH_MCMC_0_noise.png')

# %%
print('Acceptance rate: %0.1f%%' % (100*np.mean(accepted_samples)))
# Out:
# Acceptance rate: 100.0%
