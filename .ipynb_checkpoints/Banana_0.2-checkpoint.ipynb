# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow_probability import edward2 as ed
tfd = tfp.distributions
import scipy.stats as st
from mpl_toolkits.mplot3d import Axes3D

import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
from scipy.stats import multivariate_normal

def plot_true():
    x, y = np.mgrid[-4:4:.01, -6:4:.01]
    pos = np.empty(x.shape + (2,)) 
    pos[:, :, 0] = x; pos[:, :, 1] = x**2+y
    rv = multivariate_normal([0, 0], [[1, 0], [0, 1]])
    plt.contour(x, y, rv.pdf(pos))
    plt.xlabel("x1")
    plt.ylabel("x2")
plot_true()

# %% [markdown]
# #### Sampling directly from the true posterior probability density

# %% [markdown]
# <b>HMC<b>

# %%
dtype = np.float32



true_mean = [0, 0]
true_cov = [[1, 0],
                 [0, 1]]
num_results = 1000
num_chains = 1


target = tfd.MultivariateNormalFullCovariance(loc=true_mean, covariance_matrix=true_cov)

# Assume that the state is passed as a list of 1-d tensors `x` and `y`.
# Then the target log-density is defined as follows:
def target_log_prob(x, y):
  # Stack the input tensors together
  z = tf.stack([x, x**2+y], axis=-1)
  return target.log_prob(tf.squeeze(z))

# Initial state of the chain
init_state = [-3.,
              -2.]

# Run Random Walk Metropolis with normal proposal for `num_results`
# iterations for `num_chains` independent chains:
samples, kernel_results = tfp.mcmc.sample_chain(
    num_results=num_results,
    current_state=init_state,
    kernel=tfp.mcmc.HamiltonianMonteCarlo(
        target_log_prob_fn=target_log_prob,
        step_size = 0.1,
        num_leapfrog_steps = 5),
    num_burnin_steps=500,
    num_steps_between_results=1,  # Thinning.
    parallel_iterations=1)
samples = tf.stack(samples, axis=-1)

accepted = kernel_results.is_accepted

samples = samples.numpy()
accepted = accepted.numpy()
# Out:
# /Users/zhouji/.local/lib/python3.7/site-packages/tensorflow_probability/python/mcmc/sample.py:335: UserWarning: Tracing all kernel results by default is deprecated. Set the `trace_fn` argument to None (the future default value) or an explicit callback that traces the values you are interested in.
#   warnings.warn("Tracing all kernel results by default is deprecated. Set "

# %%
x1 = samples[:,0]
y1 = samples[:,1]

# %%
## plot the result
x_accepted = []
y_accepted =[]
for i in range(accepted.shape[0]):
    if accepted[i-1]==True:
        x_accepted = np.append(x_accepted,samples[i-1,0])
        y_accepted = np.append(y_accepted,samples[i-1,1])
f,(ax1,ax2) = plt.subplots(2,1,sharex =True, sharey = True)

sns.kdeplot(x_accepted,y_accepted,ax=ax1)
plot_true()

print('Acceptance rate: %0.1f%%' % (100*(x_accepted.shape[0]/num_results)))
# Out:
# Acceptance rate: 99.6%

# %% [markdown]
# <b>RMHMC<b>

# %%
dtype = np.float32

true_mean = [0, 0]
true_cov = [[1, 0],
                 [0, 1]]
num_results = 2000
num_chains = 1


target = tfd.MultivariateNormalFullCovariance(loc=true_mean, covariance_matrix=true_cov)

# Assume that the state is passed as a list of 1-d tensors `x` and `y`.
# Then the target log-density is defined as follows:
def target_log_prob(x, y):
  # Stack the input tensors together
    z = tf.stack([x, x**2+y], axis=-1)
    return target.log_prob(tf.squeeze(z))

# Initial state of the chain
init_state = [-3.,
              -4.]

# Run Random Walk Metropolis with normal proposal for `num_results`
# iterations for `num_chains` independent chains:
samples, kernel_results = tfp.mcmc.sample_chain(
    num_results=num_results,
    current_state=init_state,
    kernel=tfp.mcmc.RandomWalkMetropolis(
        target_log_prob_fn=target_log_prob),
    num_burnin_steps=500,
    num_steps_between_results=1,  # Thinning.
    parallel_iterations=1)
samples = tf.stack(samples, axis=-1)
accepted = kernel_results.is_accepted

samples = samples.numpy()
accepted = accepted.numpy()


# print('Estimated mean: {}'.format(mean_sample_mean))
# print('Estimated avg covariance: {}'.format(mean_sample_cov))
# print('Estimated covariance of covariance: {}'.format(cov_sample_cov))
# Out:
# /Users/zhouji/.local/lib/python3.7/site-packages/tensorflow_probability/python/mcmc/sample.py:335: UserWarning: Tracing all kernel results by default is deprecated. Set the `trace_fn` argument to None (the future default value) or an explicit callback that traces the values you are interested in.
#   warnings.warn("Tracing all kernel results by default is deprecated. Set "

# %%
##plot the result
x_accepted = []
y_accepted =[]
for i in range(accepted.shape[0]):
    if accepted[i-1]==True:
        x_accepted = np.append(x_accepted,samples[i-1,0])
        y_accepted = np.append(y_accepted,samples[i-1,1])
        
f,(ax1,ax2) = plt.subplots(2,1,sharex =True, sharey = True)

sns.kdeplot(x_accepted,y_accepted,ax=ax1)
plot_true()

print('Acceptance rate: %0.1f%%' % (100*(x_accepted.shape[0]/num_results)))
# Out:
# Acceptance rate: 48.0%

# %%
mean = [0, 0]
cov = [[1, 0], [0, 1]] 

x1, x2 = np.random.multivariate_normal(mean, cov, 10000).T
y1 = x1
y2 = x2+x1**2

sns.kdeplot(y1,y2)

# %%
plt.plot(y1, y2,'o')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Visual in 3D

# %%
x = y1
y = y2
# Define the borders
deltaX = (max(x) - min(x))/10
deltaY = (max(y) - min(y))/10
xmin = min(x) - deltaX
xmax = max(x) + deltaX
ymin = min(y) - deltaY
ymax = max(y) + deltaY
print(xmin, xmax, ymin, ymax)
# Create meshgrid
xx, yy = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
# Out:
# -5.009335854885385 4.241548210729745 -5.712040911817963 18.9685022432238

# %%
positions = np.vstack([xx.ravel(), yy.ravel()])
values = np.vstack([x, y])
kernel = st.gaussian_kde(values)
f = np.reshape(kernel(positions).T, xx.shape)

fig = plt.figure(figsize=(13, 7))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(xx, yy, f, rstride=1, cstride=1, cmap='coolwarm', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('PDF')
ax.set_title('Surface plot of Banana distribution 2D KDE')
fig.colorbar(surf, shrink=0.5, aspect=5) # add color bar indicating the PDF
ax.view_init(60, 30)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.gca()
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)
cfset = ax.contourf(xx, yy, f, cmap='coolwarm')
# ax.imshow(np.rot90(f), cmap='coolwarm', extent=[xmin, xmax, ymin, ymax])
cset = ax.contour(xx, yy, f, colors='k')
ax.clabel(cset, inline=1, fontsize=10)
ax.set_xlabel('X')
ax.set_ylabel('Y')
plt.title('2D Gaussian Kernel density estimation')
# Out:
# Text(0.5, 1.0, '2D Gaussian Kernel density estimation')

# %%
x1= pd.DataFrame(np.arange(-2,2,0.1))
x2= pd.DataFrame(np.arange(-2,2,0.1))
x1,x2 = np.meshgrid(x1,x2)

x_1 = pd.DataFrame(norm.pdf(x1,0,1))
x_2 = pd.DataFrame(norm.pdf(x2,0,1))

y = x_1*x_2

# %%
plt.contour(x1,x2,y)

# %%
x1,x2 = np.random.multivariate_normal([0,0], [[1,0],[0,1]], 10000).T

# %%
#Random Walk MH MCMC
@tf.function
def draw_proposal(m_current):
    
    Xi = tfd.MultivariateNormalFullCovariance(
            loc = m_current,
            covariance_matrix= [[1.,0.],[0.,1.]])
    Xi_s = tfd.Sample(Xi)
    m_proposed = Xi_s.sample()
    return m_proposed
    

def accept_or_not(m_current,m_proposed):
    if not isinstance(m_current,list):m_current = m_current.tolist()
    if not isinstance(m_proposed,list):m_proposed = m_proposed.tolist()
    
    p_accept = rv.pdf([m_proposed[0],m_proposed[0]**2+m_proposed[1]])/rv.pdf([m_current[0],m_current[0]**2+m_current[1]])
    a = np.random.rand()
    accept = a < p_accept
    
#     print("random number =",a)
#     print("probability to accept",p_accept)
    
    return accept

# %%
rv = multivariate_normal([0, 0], [[1, 0], [0, 0.3]])
def chain(step = 10):
    resultlist=[]
    initial = [-2, -4]
    m_current = initial
    for s in range(step):
        m_proposed = draw_proposal(m_current)
        m_proposed = m_proposed.numpy()
        accept = accept_or_not(m_current,m_proposed)
        if accept:
            resultlist.append([m_proposed,1])
            m_current = m_proposed
        else:
            resultlist.append([m_proposed,0])
        
    return resultlist

# %%
result = chain()

# %%
def chain_plot(result):
    chain = [result[i][0] for i in range(np.shape(result)[0])]
    x1 = [chain[i][0] for i in range(np.shape(chain)[0])]
    y1 = [chain[i][1] for i in range(np.shape(chain)[0])]
    re = pd.DataFrame(result)
    accept_point = re[1]==1
    reject_point = re[1]==0
    df_accept = pd.DataFrame(re[accept_point][0].values.tolist(), index = re[accept_point].index)
    df_reject = pd.DataFrame(re[reject_point][0].values.tolist(), index = re[reject_point].index)

    plt.figure(figsize=(15,10))
    plt.plot(df_accept[0],df_accept[1],'-o',markersize=4)
    plt.scatter(df_reject[0],df_reject[1], s=50, facecolors='none', edgecolors='r')

#     plt.contour(x, y, rv.pdf(pos))
    plot_true()
chain_plot(result)

# %% [markdown]
# <b>In an inference framework<b>

# %% [markdown]
# https://rss.onlinelibrary.wiley.com/doi/full/10.1111/j.1467-9868.2010.00765.x

# %% [markdown]
# https://bitbucket.org/geomstatcomp/lagrangian-monte-carlo/src/master/Banana%20Shaped%20Distribution/Fig3_histBanana_exat.m
#
# \begin{equation}
# y_{1}, \ldots, y_{n} \sim \mathcal{N}\left(\theta_{1}+\theta_{2}^{2}, \sigma_{y}^{2}\right)
# \end{equation}
#
# \begin{equation}
# \theta_{1}+\theta_{2}^{2}=c
# \end{equation}

# %%
# simulated data
D = 2 # dimention
c = 0 # constant
N = 100000 # number of data
sigma2y = 1 
y = np.random.normal(loc =c, scale = 1, size = N) ## data

std = np.std(y)
mean = np.mean(y)
n = -N/2*np.log(2*3.14)-N*np.log(std)
n
# Out:
# -91745.12909318027

# %% [markdown]
# Create a likelihood function by hand

# %%
prior = tf.convert_to_tensor([0.,0.])
cov = tf.convert_to_tensor([[1.,0.],[0.,1.]])

# %% [markdown]
# \begin{equation}
# \pi(y | \mu, \sigma)=(2 \pi)^{-\frac{N}{2}} \sigma^{-N} \exp \left(-\frac{1}{2} \frac{N}{\sigma^{2}}(\langle y\rangle-\mu)^{2}\right) \exp \left(-\frac{1}{2} \frac{N}{\sigma^{2}}\left(\left\langle y^{2}\right\rangle-\langle y\rangle^{2}\right)\right)
# \end{equation}

# %%
def f(theta1,theta2):
    k = theta2+ tf.pow(theta1,2)
    x = tf.random.normal([],mean = k,stddev = 1)
    return tf.convert_to_tensor(x,dtype=tf.float32)

mvn = tfd.MultivariateNormalFullCovariance(loc=prior, covariance_matrix=cov)

def target_log(theta1, theta2):
    z = tf.stack([theta1, theta2], axis=-1)
    
    log_likelihood = -(1/2)* ((mean-f(theta1,theta2))**2)/(std**2)

#     log_posterior = log_likelihood + mvn.log_prob(tf.squeeze(z))
    return(log_likelihood)

qtheta1 = -2*tf.ones([], dtype=tf.float32)
qtheta2 = -2*tf.ones([], dtype=tf.float32)

# %%
Nsamples = 12000

kernel=tfp.mcmc.RandomWalkMetropolis(
        target_log_prob_fn=target_log)

samples, kernel_results = tfp.mcmc.sample_chain(
    num_results=Nsamples,
    current_state=[qtheta1, qtheta2],
    kernel=kernel,
    num_burnin_steps=2000)

samples = tf.stack(samples, axis=-1)

accepted = kernel_results.is_accepted
samples = samples.numpy()
accepted = accepted.numpy()
# Out:
# /Users/zhouji/.local/lib/python3.7/site-packages/tensorflow_probability/python/mcmc/sample.py:335: UserWarning: Tracing all kernel results by default is deprecated. Set the `trace_fn` argument to None (the future default value) or an explicit callback that traces the values you are interested in.
#   warnings.warn("Tracing all kernel results by default is deprecated. Set "

# %% [markdown]
# Draw mcmc from likelihood, $\theta_1$,$\theta_2$ are non‐identifiable without any additional information beyond the observations.: any values such that inline image for some constant c explain the data equally well.

# %%
x1 = samples[:,0]
y1 = samples[:,1]

x_accepted = []
y_accepted =[]
for i in range(accepted.shape[0]):
    if accepted[i-1]==True:
        x_accepted = np.append(x_accepted,samples[i-1,0])
        y_accepted = np.append(y_accepted,samples[i-1,1])
        
fig,(ax1,ax2) = plt.subplots(2,1,sharex =True, sharey = True)

sns.kdeplot(x_accepted,y_accepted,ax=ax1)
# ax1.plot(x_accepted,y_accepted)
plot_true()
print('Acceptance rate: %0.1f%%' % (100*(x_accepted.shape[0]/Nsamples)))
# Out:
# Acceptance rate: 18.1%

# %% [markdown]
# Sample from Prior

# %%
mvn = tfd.MultivariateNormalFullCovariance(loc=prior, covariance_matrix=cov)

def target_log(theta1, theta2):
    z = tf.stack([theta1, theta2], axis=-1)
    log_prior = mvn.log_prob(tf.squeeze(z))
    return(log_prior)

qtheta1 = -2*tf.ones([], dtype=tf.float32)
qtheta2 = -2*tf.ones([], dtype=tf.float32)

Nsamples = 12000

kernel=tfp.mcmc.RandomWalkMetropolis(
        target_log_prob_fn=target_log)

samples, kernel_results = tfp.mcmc.sample_chain(
    num_results=Nsamples,
    current_state=[qtheta1, qtheta2],
    kernel=kernel,
    num_burnin_steps=2000)

samples = tf.stack(samples, axis=-1)

accepted = kernel_results.is_accepted
samples = samples.numpy()
accepted = accepted.numpy()

x1 = samples[:,0]
y1 = samples[:,1]

x_accepted = []
y_accepted =[]
for i in range(accepted.shape[0]):
    if accepted[i-1]==True:
        x_accepted = np.append(x_accepted,samples[i-1,0])
        y_accepted = np.append(y_accepted,samples[i-1,1])
        
fig,(ax1,ax2) = plt.subplots(2,1,sharex =True, sharey = True)

sns.kdeplot(x_accepted,y_accepted,ax=ax1)
# ax1.plot(x_accepted,y_accepted)
plot_true()
print('Acceptance rate: %0.1f%%' % (100*(x_accepted.shape[0]/Nsamples)))
# Out:
# /Users/zhouji/.local/lib/python3.7/site-packages/tensorflow_probability/python/mcmc/sample.py:335: UserWarning: Tracing all kernel results by default is deprecated. Set the `trace_fn` argument to None (the future default value) or an explicit callback that traces the values you are interested in.
#   warnings.warn("Tracing all kernel results by default is deprecated. Set "
# Acceptance rate: 55.9%

# %% [markdown]
# combine likelihood and prior: draw sample on posterior by RWMC

# %%
prior = tf.convert_to_tensor([0.,0.])
cov = tf.convert_to_tensor([[10,0.],[0.,10]])

mvn = tfd.MultivariateNormalFullCovariance(loc=prior, covariance_matrix=cov)

def log_post(theta1, theta2):
    z = tf.stack([theta1, theta2], axis=-1)
    
    log_likelihood = -(1/2)* ((mean-f(theta1,theta2))**2)/(std**2)

    log_prior = mvn.log_prob(tf.squeeze(z))
    log_posterior = log_likelihood+log_prior
    return(log_posterior)

qtheta1 = -2*tf.ones([], dtype=tf.float32)
qtheta2 = -2*tf.ones([], dtype=tf.float32)

Nsamples = 12000

kernel=tfp.mcmc.RandomWalkMetropolis(
        target_log_prob_fn=log_post)

samples, kernel_results = tfp.mcmc.sample_chain(
    num_results=Nsamples,
    current_state=[qtheta1, qtheta2],
    kernel=kernel,
    num_burnin_steps=2000)

samples = tf.stack(samples, axis=-1)

accepted = kernel_results.is_accepted
samples = samples.numpy()
accepted = accepted.numpy()

x1 = samples[:,0]
y1 = samples[:,1]

x_accepted = []
y_accepted =[]
for i in range(accepted.shape[0]):
    if accepted[i-1]==True:
        x_accepted = np.append(x_accepted,samples[i-1,0])
        y_accepted = np.append(y_accepted,samples[i-1,1])
        
fig,(ax1,ax2) = plt.subplots(2,1,sharex =True, sharey = True)

sns.kdeplot(x_accepted,y_accepted,ax=ax1)
# ax1.plot(x_accepted,y_accepted)
plot_true()
print('Acceptance rate: %0.1f%%' % (100*(x_accepted.shape[0]/Nsamples)))
# Out:
# /Users/zhouji/.local/lib/python3.7/site-packages/tensorflow_probability/python/mcmc/sample.py:335: UserWarning: Tracing all kernel results by default is deprecated. Set the `trace_fn` argument to None (the future default value) or an explicit callback that traces the values you are interested in.
#   warnings.warn("Tracing all kernel results by default is deprecated. Set "
# Acceptance rate: 40.5%

# %% [markdown]
# Test HMC, not correct :(

# %%
@tf.function
def f(theta1,theta2):
    k = theta2+ tf.pow(theta1,2)
    x = tf.random.normal([],mean = k,stddev = 1)
    return tf.convert_to_tensor(x,dtype=tf.float32)

prior = tf.convert_to_tensor([0.,0.])
cov = tf.convert_to_tensor([[1,0.],[0.,1]])

mvn = tfd.MultivariateNormalFullCovariance(loc=prior, covariance_matrix=cov)

@tf.function
def log_post(theta1, theta2):
    z = tf.stack([theta1, theta2], axis=-1)
    
    log_likelihood = -(1/2)* ((mean-f(theta1,theta2))**2)/(std**2)

    log_prior = mvn.log_prob(tf.squeeze(z))
    log_posterior = log_likelihood+log_prior
    return(log_posterior)

qtheta1 = -2*tf.ones([], dtype=tf.float32)
qtheta2 = -2*tf.ones([], dtype=tf.float32)

Nsamples = 5000

samples, kernel_results = tfp.mcmc.sample_chain(
    num_results=num_results,
    current_state=[qtheta1, qtheta2],
    kernel=tfp.mcmc.HamiltonianMonteCarlo(
        target_log_prob_fn=target_log_prob,
        step_size = 0.1,
        num_leapfrog_steps = 20),
    num_burnin_steps=1000,
    num_steps_between_results=1,  # Thinning.
    parallel_iterations=1)

samples = tf.stack(samples, axis=-1)

accepted = kernel_results.is_accepted
samples = samples.numpy()
accepted = accepted.numpy()

x1 = samples[:,0]
y1 = samples[:,1]

x_accepted = []
y_accepted =[]
for i in range(accepted.shape[0]):
    if accepted[i-1]==True:
        x_accepted = np.append(x_accepted,samples[i-1,0])
        y_accepted = np.append(y_accepted,samples[i-1,1])
        
fig,(ax1,ax2) = plt.subplots(2,1,sharex =True, sharey = True)

sns.kdeplot(x_accepted,y_accepted,ax=ax1)
# ax1.plot(x_accepted,y_accepted)
plot_true()
print('Acceptance rate: %0.1f%%' % (100*(x_accepted.shape[0]/Nsamples)))

# %% [markdown]
# ### Hessian MCMC

# %% [markdown]
# Calculate MAP - Gradient decent

# %%
@tf.function
def matrixcompute(matrix1,matrix2,Cov):
    matrix1 = tf.cast(matrix1,tf.float32)
    matrix2 = tf.cast(matrix2,tf.float32)
    matrix = tf.subtract(matrix1, matrix2)
    matrix = tf.reshape(matrix,[matrix.shape[0],1])
    matrix_T = tf.transpose(matrix)
    Cov_inv = tf.linalg.inv(Cov)
    result = tf.multiply(tf.constant(1/2),tf.matmul(tf.matmul(matrix_T,Cov_inv),matrix))
    return result

# %% [markdown]
# #### negative log of the posterior
# \begin{equation}
# \left(\frac{1}{2}\left\|\mathbf{f}(\mathrm{m})-\mathbf{d}_{\mathrm{obs}}\right\|_{\mathrm{\Gamma}_{\mathrm{noise}}^{-1}}^{2}+\frac{1}{2}\left\|\mathrm{m}-\mathrm{m}_{\mathrm{prior}}\right\|_{C_{\mathrm{prior}}^{-1}}^{2}\right)
# \end{equation}

# %%
@tf.function

def f(theta1,theta2):
    k = theta2+ tf.pow(theta1,2)
    x = tf.random.normal([],mean = k,stddev = 1)
    return tf.convert_to_tensor(x,dtype=tf.float32)

def loss(theta1,theta2):
    y  = f(theta1, theta2)
    term1 = matrixcompute()
